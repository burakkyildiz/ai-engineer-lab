# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
torch.backends.mps.is_available() # Metal Performance Shaders(mps)
# Out:
# True

# %%
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
device
# Out:
# 'mps'

# %%
if torch.backends.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

# %%
device
# Out:
# 'mps'

# %%
tensor = torch.tensor([1,2,3])

# %%
tensor
# Out:
# tensor([1, 2, 3])

# %%
tensor.device
# Out:
# device(type='cpu')

# %%
# 1-manual

# %%
tensor_on_gpu = tensor.to(device)

# %%
tensor_on_gpu
# Out:
# tensor([1, 2, 3], device='mps:0')

# %%
tensor.numpy()
# Out:
# array([1, 2, 3])

# %%
tensor_on_gpu.numpy() # tensor cpu yu kullanmak zorunda
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 tensor_on_gpu.numpy()
#
# TypeError: can't convert mps:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
tensor_on_gpu.cpu().numpy()
# Out:
# array([1, 2, 3])

# %%
# 2-context manager

# %%
with torch.device(device):
    tensor2 = torch.tensor([1,2,3]) # context managerin icinde oldugu icin device = mps
    layer = torch.nn.Linear(20,30)

# %%
tensor2.device
# Out:
# device(type='mps', index=0)

# %%
layer.weight.device
# Out:
# device(type='mps', index=0)

# %%
#---------

# %%
tensor3 = torch.tensor([1,2,3])

# %%
tensor3.device # context manager in disinda oldugu icin device = cpu
# Out:
# device(type='cpu')

# %%
# 3-torch.set_default_device

# %%
device
# Out:
# 'mps'

# %%
torch.set_default_device(device)

# %%
tensor4 = torch.tensor([1,2,3])
layer2 = torch.nn.Linear(20,40)

# %%
tensor4.device
# Out:
# device(type='mps', index=0)

# %%
layer2.weight.device
# Out:
# device(type='mps', index=0)

# %%
tensor3.device
# Out:
# device(type='cpu')
