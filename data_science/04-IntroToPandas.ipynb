# %%
import numpy as np
import pandas as pd

# %%
grades = {"Burak" : 50, "Ahmet" : 60, "Cem" : 30}

# %%
pd.Series(grades)
# Out:
# Burak    50
# Ahmet    60
# Cem      30
# dtype: int64

# %%
names = ["Burak", "Ahmet", "Cem"]
grades = [50,60,30]

# %%
pd.Series(names)
# Out:
# 0    Burak
# 1    Ahmet
# 2      Cem
# dtype: object

# %%
pd.Series(grades)
# Out:
# 0    50
# 1    60
# 2    30
# dtype: int64

# %%
pd.Series(grades, names)
# Out:
# Burak    50
# Ahmet    60
# Cem      30
# dtype: int64

# %%
pd.Series(data=grades, index=names)
# Out:
# Burak    50
# Ahmet    60
# Cem      30
# dtype: int64

# %%
# with numpy

# %%
numpy_array = np.array([50,40,30,20])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    40
# 2    30
# 3    20
# dtype: int64

# %%
#arithmetic

# %%
contest_result = pd.Series([10,5,100],["Burak","Ahmet","Cem"])

# %%
contest_result2 = pd.Series([20,50,10],["Burak","Ahmet","Cem"])

# %%
contest_result["Burak"]
# Out:
# 10

# %%
contest_result2["Cem"]
# Out:
# 10

# %%
final_result = contest_result + contest_result2

# %%
final_result
# Out:
# Burak     30
# Ahmet     55
# Cem      110
# dtype: int64

# %%
contest_result * contest_result2
# Out:
# Burak     200
# Ahmet     250
# Cem      1000
# dtype: int64

# %%
contest_result - contest_result2
# Out:
# Burak   -10
# Ahmet   -45
# Cem      90
# dtype: int64

# %%
contest_result / contest_result2
# Out:
# Burak     0.5
# Ahmet     0.1
# Cem      10.0
# dtype: float64

# %%
# if indices are different

# %%
different_series = pd.Series([20,30,40,50],["a","b","c","d"])

# %%
different_series_2 = pd.Series([10,5,3,1],["a","c","f","g"])

# %%
different_series + different_series_2
# Out:
# a    30.0
# b     NaN
# c    45.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
